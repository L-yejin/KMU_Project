# %% [markdown]
# # 구글 드라이브 mount해오기

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
pwd

# %%
# %cd /content/drive/MyDrive/딥러닝/최종코드

# %% [markdown]
# # Git clone 해오기
#
# 출처| https://github.com/superhighlevel/ChromaGan_Pytorch_Remake

# %%
# !git clone https://github.com/superhighlevel/ChromaGan_Pytorch_Remake.git yejin_ChromaGAN

# %% [markdown]
# # version 맞추기

# %%
# %cd yejin_ChromaGAN

# %%
# 현재 파이썬 버전 확인
# !python --version

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# %% [markdown]
# 위 코드가 다 실행된 후, 런타임이 다시 연결되면 아래 코드 실행

# %%
import condacolab
condacolab.check()

# %% [markdown]
# python version 3.7로 설치

# %%
# !conda create -n ChromaGAN python=3.7

# %% [markdown]
# ## 필요한 라이브러리 설치

# %%
# !pip install -r requirements.txt
# !pip install torch==1.9.1+cu111 torchvision==0.10.1+cu111 torchaudio==0.9.1 torchtext==0.10.1 -f https://download.pytorch.org/whl/torch_stable.html --user

# %% [markdown]
# # config에서 경로 수정 후 실행

# %% [markdown]
# training

# %%
# !python main.py --mode 1

# %% [markdown]
# 결과만 출력하고 싶을 때 실행

# %%
# !python main.py --mode 2
