# %% [markdown]
# # 구글 드라이브 mount해오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # import

# %%
import pickle

import pandas as pd
import numpy as np
import random
import matplotlib.pylab as plt
import scipy.stats as stats
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.stats.outliers_influence import OLSInfluence

import os 
import io
import zipfile
from zipfile import ZipFile
import requests
import tensorflow as tf
import cv2
import json
import matplotlib.image as img
from PIL import Image

from tqdm import tqdm
import time

# %% [markdown]
# # 시각화
#
# 저장된 일부 Loss라도 저장한 결과입니다

# %%
D_path = '/content/drive/MyDrive/딥러닝/최종코드/yejin_ChromaGAN/models/Loss_D.pkl'
G_path = '/content/drive/MyDrive/딥러닝/최종코드/yejin_ChromaGAN/models/Loss_G.pkl'

# %%
with open(D_path,"rb") as fr:
    loss_D = pickle.load(fr)
with open(G_path,"rb") as fr:
    loss_G = pickle.load(fr)

# %%
D_lst = []
for i in loss_D[0]:
  D_lst.append(i.detach().cpu().numpy())

# %%
G_lst = []
for i in loss_G[0]:
  G_lst.append(i.detach().cpu().numpy())

# %%
import matplotlib.pyplot as plt

plt.plot(D_lst)
plt.show()

# %%
plt.plot(G_lst)
plt.show()
